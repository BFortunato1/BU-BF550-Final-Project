# %%
import numpy as np
import pandas as pd
import scipy 
from matplotlib import pyplot as plt


def TB():
    filesA = ["C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\1A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\2A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\3A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\4A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\5A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\6A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\7A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\8A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\9A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\10A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\11A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\12A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\13A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\14A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\15A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\16A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\17A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\18A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\19A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\20A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\21A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\22A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\23A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\24A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\25A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\26A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\27A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\28A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\29A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\30A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\31A_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\32A_pm.fna",

        
    ]
    
    filesB = ["C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\1B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\2B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\3B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\4B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\5B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\6B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\7B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\8B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\9B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\10B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\11B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\12B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\13B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\14B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\15B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\16B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\17B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\18B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\19B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\20B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\21B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\22B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\23B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\24B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\25B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\26B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\27B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\28B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\29B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\30B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\31B_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\32B_pm.fna",

        
    ]
    
    filesC = ["C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N1_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N2_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N3_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N4_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N5_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N6_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N7_pm.fna",
"C:\\Users\\b42na\\Documents\\BF550\\Final\\FinalP\\N8_pm.fna"
        
    ]
    finalA = []
    finalB = []
    finalC = []
    platoA = []
    platoB = []
    platoC = []

    for ta in filesA:
        dictionA = {}
        file = open(ta, 'r')
        count = []
        for line in file:
            if len(line) > 185:
                for num in range(len(line)):
                    for x in range(4,1000):
                        if line[num:num+x] in line[num+x:]:
                            count.append(line[num:num+x])
                        if (line[num:num+x])[::-1] in line[num+x:]:
                            count.append((line[num:num+x])[::-1])
            for amp in count:
                if amp not in dictionA:
                    dictionA[amp] = (count.count(amp)+1)
            
                    
        finalA.append([dictionA])
    for lis in finalA:
        triggerA = []
        for d in lis:
            for al in d:
                triggerA.append(d[al])
        platoA.append(triggerA)
    dataA = []
    for vic in platoA:
        pd_series = pd.Series(vic)
        counts = pd_series.value_counts()
        entropy = scipy.stats.entropy(counts)
        dataA.append(entropy)
        
    for tb in filesB:
        dictionB = {}
        file = open(tb, 'r')
        count = []
        for line in file:
            if len(line) > 190:
                for num in range(len(line)):
                    for x in range(4,1000):
                        if line[num:num+x] in line[num+x:]:
                            count.append(line[num:num+x])
                        if (line[num:num+x])[::-1] in line[num+x:]:
                            count.append((line[num:num+x])[::-1])
            for amp in count:
                if amp not in dictionB:
                    dictionB[amp] = (count.count(amp)+1)
            
                    
        finalB.append([dictionB])
    for lis in finalB:
        triggerB = []
        for d in lis:
            for al in d:
                triggerB.append(d[al])
        platoB.append(triggerB)
    dataB = []
    for vic in platoB:
        pd_series = pd.Series(vic)
        counts = pd_series.value_counts()
        entropy = scipy.stats.entropy(counts)
        dataB.append(entropy)
        
    for tc in filesC:
        dictionC = {}
        file = open(tc, 'r')
        count = []
        for line in file:
            if len(line) > 190:
                for num in range(len(line)):
                    for x in range(4,1000):
                        if line[num:num+x] in line[num+x:]:
                            count.append(line[num:num+x])
                        if (line[num:num+x])[::-1] in line[num+x:]:
                            count.append((line[num:num+x])[::-1])
            for amp in count:
                if amp not in dictionC:
                    dictionC[amp] = (count.count(amp)+1)
            
                    
        finalC.append([dictionC])
    for lis in finalC:
        triggerC = []
        for d in lis:
            for al in d:
                triggerC.append(d[al])
        platoC.append(triggerC)
    dataC = []
    for vic in platoC:
        pd_series = pd.Series(vic)
        counts = pd_series.value_counts()
        entropy = scipy.stats.entropy(counts)
        dataC.append(entropy)


    plt.rcParams['figure.figsize'] = (26,16)
    plt.style.use('seaborn')
    fig, ax = plt.subplots()
    plt.plot(dataA, label = 'Group A', color = 'red')
    plt.plot(dataB, label = 'Group B', color = 'blue')
    plt.plot(dataC, label = 'Group H(?)', color = 'green')
    ax.legend(loc = 'best', fontsize=12)
    plt.title('Shannon Weaver Index Analysis; Diversity of Amplicons in TB Presenting Patients', fontsize = 13)
    ax.set_xlabel("Sample Base Pair Length", fontsize = 13, color = 'black')
    ax.set_ylabel("PDF: Entropy of Amplicon Diversity", fontsize = 13, color = 'black') 
    ax.legend(loc = 'best', fontsize=12)
    ax.tick_params(axis='x', colors='black')
    ax.tick_params(axis='y', colors='black')

    plt.show()

# %%
TB()
